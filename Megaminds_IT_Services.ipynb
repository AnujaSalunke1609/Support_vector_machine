# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Loading dataset
data=pd.read_csv("/content/Datasets.csv")

# %%
data.head()
# Out:
#                                       ID      Sender_IP  Sender_Port  \
# 0   10.42.0.211-104.97.95.172-59522-80-6  192.168.2.112         2142
# 1  216.58.217.68-10.42.0.211-443-59345-6  147.32.84.170         2108
# 2    10.42.0.151-54.192.38.7-52510-443-6  147.32.84.170         3805
# 3  216.58.219.206-10.42.0.42-443-53294-6  147.32.84.180         3008
# 4       10.42.0.1-10.42.0.42-53-62597-17  147.32.84.160        11697
#
#          Target_IP  Target_Port  Transport_Protocol  Duration  AvgDuration  \
# 0   75.126.101.175          443                   1      4.28     6.039028
# 1    208.100.48.73           22                   1      3.00     1.500000
# 2   125.14.233.194           22                   1      0.00     1.500000
# 3  205.188.146.193           25                   1      2.96     2.021923
# 4   184.173.217.40          443                   1      0.15     0.159373
#
#     PBS      AvgPBS   TBS    PBR       AvgPBR    TBR  Missed_Bytes  \
# 0  1174  856.833333  1894  11862  27450.72222  12462             0
# 1     0    0.000000   192      0      0.00000      0             0
# 2     0    0.000000    96      0      0.00000      0             0
# 3     0    0.000000    96      0      0.00000      0             0
# 4     0    0.000000    96      0      0.00000     40             0
#
#    Packets_Sent  Packets_Received      SRPR  class
# 0            18                15  0.833333      0
# 1             4                 0  0.000000      1
# 2             2                 0  0.000000      1
# 3             2                 0  0.000000      1
# 4             2                 1  0.500000      1

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.describe().T
# Out:
#                      count          mean            std   min          25%  \
# Sender_Port         5472.0  16649.802997   18265.060508  53.0  2690.000000
# Target_Port         5472.0   3544.247259    9404.524921  21.0    53.000000
# Transport_Protocol  5472.0      1.389072       0.487584   1.0     1.000000
# Duration            5472.0     12.964750     305.059762   0.0     0.050000
# AvgDuration         5472.0     21.341809     883.079233   0.0     0.218569
# PBS                 5472.0    317.964547    3732.302430   0.0     0.000000
# AvgPBS              5472.0    729.822036   18639.387014   0.0    28.750000
# TBS                 5472.0    759.547332    6924.407943   0.0    80.000000
# PBR                 5472.0  13004.136696  184746.092092   0.0     0.000000
# AvgPBR              5472.0  13225.167725  131233.650657   0.0     0.000000
# TBR                 5472.0  13159.618787  188051.067070   0.0     0.000000
# Missed_Bytes        5472.0    462.317069   17168.330107   0.0     0.000000
# Packets_Sent        5472.0     10.211075     104.135551   0.0     1.000000
# Packets_Received    5472.0     11.732822     111.630205   0.0     0.000000
# SRPR                5472.0      0.711110       0.601317   0.0     0.000000
# class               5472.0      0.629934       0.482866   0.0     0.000000
#
#                             50%           75%           max
# Sender_Port         4840.500000  32245.000000  6.552200e+04
# Target_Port           80.000000    139.000000  6.550000e+04
# Transport_Protocol     1.000000      2.000000  2.000000e+00
# Duration               0.480000      3.060000  2.208371e+04
# AvgDuration            1.500000      7.583472  6.517823e+04
# PBS                   49.000000    103.000000  1.562890e+05
# AvgPBS                56.048880    141.422819  1.062472e+06
# TBS                  120.000000    361.250000  3.256740e+05
# PBR                  101.000000    679.250000  8.986288e+06
# AvgPBR               189.257762   3805.433824  6.142982e+06
# TBR                  124.000000    838.000000  9.231445e+06
# Missed_Bytes           0.000000      0.000000  8.640720e+05
# Packets_Sent           2.000000      6.000000  6.561000e+03
# Packets_Received       1.000000      5.000000  6.510000e+03
# SRPR                   0.833333      1.000000  8.000000e+00
# class                  1.000000      1.000000  1.000000e+00

# %%
data.dtypes
# Out:
# ID                     object
# Sender_IP              object
# Sender_Port             int64
# Target_IP              object
# Target_Port             int64
# Transport_Protocol      int64
# Duration              float64
# AvgDuration           float64
# PBS                     int64
# AvgPBS                float64
# TBS                     int64
# PBR                     int64
# AvgPBR                float64
# TBR                     int64
# Missed_Bytes            int64
# Packets_Sent            int64
# Packets_Received        int64
# SRPR                  float64
# class                   int64
# dtype: object

# %%
data.corr()
# Out:
# <ipython-input-11-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                     Sender_Port  Target_Port  Transport_Protocol  Duration  \
# Sender_Port            1.000000     0.124804            0.513542 -0.011907
# Target_Port            0.124804     1.000000            0.331738  0.030885
# Transport_Protocol     0.513542     0.331738            1.000000 -0.001063
# Duration              -0.011907     0.030885           -0.001063  1.000000
# AvgDuration           -0.012241     0.013210           -0.008008  0.989114
# PBS                    0.015047     0.173476           -0.004522  0.039593
# AvgPBS                -0.008215     0.079277           -0.016184  0.019872
# TBS                   -0.025016     0.128563           -0.047389  0.055096
# PBR                   -0.044665    -0.010766           -0.054726  0.006106
# AvgPBR                -0.064701    -0.000513           -0.076553  0.007366
# TBR                   -0.043742    -0.018215           -0.054312  0.005686
# Missed_Bytes           0.009802     0.018282           -0.021492  0.010464
# Packets_Sent          -0.045337     0.012791           -0.056919  0.053390
# Packets_Received      -0.053972    -0.012357           -0.068994  0.045934
# SRPR                  -0.123383     0.061065           -0.009993  0.006198
# class                  0.042804    -0.401458           -0.272599 -0.037100
#
#                     AvgDuration       PBS    AvgPBS       TBS       PBR  \
# Sender_Port           -0.012241  0.015047 -0.008215 -0.025016 -0.044665
# Target_Port            0.013210  0.173476  0.079277  0.128563 -0.010766
# Transport_Protocol    -0.008008 -0.004522 -0.016184 -0.047389 -0.054726
# Duration               0.989114  0.039593  0.019872  0.055096  0.006106
# AvgDuration            1.000000  0.023335  0.018573  0.049155  0.001236
# PBS                    0.023335  1.000000  0.116544  0.750853  0.009603
# AvgPBS                 0.018573  0.116544  1.000000  0.082973  0.021932
# TBS                    0.049155  0.750853  0.082973  1.000000  0.575823
# PBR                    0.001236  0.009603  0.021932  0.575823  1.000000
# AvgPBR                 0.004430  0.011466  0.182985  0.517525  0.910757
# TBR                    0.001633  0.009232 -0.000047  0.571466  0.994614
# Missed_Bytes           0.001764  0.005377  0.235134  0.049074  0.091075
# Packets_Sent           0.048949  0.071862  0.028416  0.655166  0.942467
# Packets_Received       0.042133  0.043168  0.006953  0.516409  0.943154
# SRPR                   0.005702  0.021483  0.030487  0.052335  0.089188
# class                 -0.024742 -0.036707 -0.015457 -0.008202  0.007723
#
#                       AvgPBR       TBR  Missed_Bytes  Packets_Sent  \
# Sender_Port        -0.064701 -0.043742      0.009802     -0.045337
# Target_Port        -0.000513 -0.018215      0.018282      0.012791
# Transport_Protocol -0.076553 -0.054312     -0.021492     -0.056919
# Duration            0.007366  0.005686      0.010464      0.053390
# AvgDuration         0.004430  0.001633      0.001764      0.048949
# PBS                 0.011466  0.009232      0.005377      0.071862
# AvgPBS              0.182985 -0.000047      0.235134      0.028416
# TBS                 0.517525  0.571466      0.049074      0.655166
# PBR                 0.910757  0.994614      0.091075      0.942467
# AvgPBR              1.000000  0.895541      0.090750      0.847780
# TBR                 0.895541  1.000000      0.040148      0.934675
# Missed_Bytes        0.090750  0.040148      1.000000      0.069985
# Packets_Sent        0.847780  0.934675      0.069985      1.000000
# Packets_Received    0.856620  0.950859      0.045167      0.809365
# SRPR                0.086704  0.098504      0.005058      0.070889
# class               0.000221  0.012006     -0.009386      0.002335
#
#                     Packets_Received      SRPR     class
# Sender_Port                -0.053972 -0.123383  0.042804
# Target_Port                -0.012357  0.061065 -0.401458
# Transport_Protocol         -0.068994 -0.009993 -0.272599
# Duration                    0.045934  0.006198 -0.037100
# AvgDuration                 0.042133  0.005702 -0.024742
# PBS                         0.043168  0.021483 -0.036707
# AvgPBS                      0.006953  0.030487 -0.015457
# TBS                         0.516409  0.052335 -0.008202
# PBR                         0.943154  0.089188  0.007723
# AvgPBR                      0.856620  0.086704  0.000221
# TBR                         0.950859  0.098504  0.012006
# Missed_Bytes                0.045167  0.005058 -0.009386
# Packets_Sent                0.809365  0.070889  0.002335
# Packets_Received            1.000000  0.145035  0.003008
# SRPR                        0.145035  1.000000 -0.320308
# class                       0.003008 -0.320308  1.000000

# %%
import seaborn as sns

# %%
cat_feature=[column for column in data.columns if data[column].dtype=="O"]

# %%
cat_feature
# Out:
# ['ID', 'Sender_IP', 'Target_IP']

# %%
numerical_feature=[column for column in data.columns if data[column].dtype!="O"]

# %%
numerical_feature
# Out:
# ['Sender_Port',
#  'Target_Port',
#  'Transport_Protocol',
#  'Duration',
#  'AvgDuration',
#  'PBS',
#  'AvgPBS',
#  'TBS',
#  'PBR',
#  'AvgPBR',
#  'TBR',
#  'Missed_Bytes',
#  'Packets_Sent',
#  'Packets_Received',
#  'SRPR',
#  'class']

# %%
data.nunique()
# Out:
# ID                    5220
# Sender_IP              279
# Sender_Port           3975
# Target_IP             1940
# Target_Port            542
# Transport_Protocol       2
# Duration              1313
# AvgDuration           1996
# PBS                    692
# AvgPBS                1473
# TBS                   1073
# PBR                   1476
# AvgPBR                1506
# TBR                   1531
# Missed_Bytes           132
# Packets_Sent           145
# Packets_Received       163
# SRPR                   376
# class                    2
# dtype: int64

# %%
data.shape
# Out:
# (5472, 19)

# %%
data[numerical_feature]
# Out:
#       Sender_Port  Target_Port  Transport_Protocol  Duration  AvgDuration  \
# 0            2142          443                   1      4.28     6.039028
# 1            2108           22                   1      3.00     1.500000
# 2            3805           22                   1      0.00     1.500000
# 3            3008           25                   1      2.96     2.021923
# 4           11697          443                   1      0.15     0.159373
# ...           ...          ...                 ...       ...          ...
# 5467        51163           80                   1     15.08    14.057467
# 5468        54167           53                   2      0.00     0.012399
# 5469         1025           53                   2      0.12     9.772956
# 5470         1910           80                   1      0.45     0.566667
# 5471         2775           22                   1      0.29     0.290000
#
#        PBS      AvgPBS   TBS    PBR        AvgPBR    TBR  Missed_Bytes  \
# 0     1174  856.833333  1894  11862  27450.722220  12462             0
# 1        0    0.000000   192      0      0.000000      0             0
# 2        0    0.000000    96      0      0.000000      0             0
# 3        0    0.000000    96      0      0.000000      0             0
# 4        0    0.000000    96      0      0.000000     40             0
# ...    ...         ...   ...    ...           ...    ...           ...
# 5467   596  580.106667   848    166    162.240000    338             0
# 5468    35   38.840843    63    110    141.052849      0             0
# 5469    76  356.485402   132    219    927.129562    247             0
# 5470    64   54.333333   272    182   3572.000000    350             0
# 5471     0    0.000000    96      0      0.000000     40             0
#
#       Packets_Sent  Packets_Received      SRPR  class
# 0               18                15  0.833333      0
# 1                4                 0  0.000000      1
# 2                2                 0  0.000000      1
# 3                2                 0  0.000000      1
# 4                2                 1  0.500000      1
# ...            ...               ...       ...    ...
# 5467             6                 4  0.666667      1
# 5468             1                 0  0.000000      1
# 5469             2                 1  0.500000      1
# 5470             5                 4  0.800000      1
# 5471             2                 1  0.500000      1
#
# [5472 rows x 16 columns]

# %%
# In the dataset there is no null values
#also label encoding is notrequired

# %%
columns_to_drop=["Sender_Port","Target_Port","Transport_Protocol","ID","Sender_IP","Target_IP"]
data=data.drop(columns=columns_to_drop)

# %%
data.head()
# Out:
#    Duration  AvgDuration   PBS      AvgPBS   TBS    PBR       AvgPBR    TBR  \
# 0      4.28     6.039028  1174  856.833333  1894  11862  27450.72222  12462
# 1      3.00     1.500000     0    0.000000   192      0      0.00000      0
# 2      0.00     1.500000     0    0.000000    96      0      0.00000      0
# 3      2.96     2.021923     0    0.000000    96      0      0.00000      0
# 4      0.15     0.159373     0    0.000000    96      0      0.00000     40
#
#    Missed_Bytes  Packets_Sent  Packets_Received      SRPR  class
# 0             0            18                15  0.833333      0
# 1             0             4                 0  0.000000      1
# 2             0             2                 0  0.000000      1
# 3             0             2                 0  0.000000      1
# 4             0             2                 1  0.500000      1

# %%
data.head()
# Out:
#    Duration  AvgDuration   PBS      AvgPBS   TBS    PBR       AvgPBR    TBR  \
# 0      4.28     6.039028  1174  856.833333  1894  11862  27450.72222  12462
# 1      3.00     1.500000     0    0.000000   192      0      0.00000      0
# 2      0.00     1.500000     0    0.000000    96      0      0.00000      0
# 3      2.96     2.021923     0    0.000000    96      0      0.00000      0
# 4      0.15     0.159373     0    0.000000    96      0      0.00000     40
#
#    Missed_Bytes  Packets_Sent  Packets_Received      SRPR  class
# 0             0            18                15  0.833333      0
# 1             0             4                 0  0.000000      1
# 2             0             2                 0  0.000000      1
# 3             0             2                 0  0.000000      1
# 4             0             2                 1  0.500000      1

# %%
data.shape
# Out:
# (5472, 13)

# %%
x=data.drop("class",axis=1)

# %%
x
# Out:
#       Duration  AvgDuration   PBS      AvgPBS   TBS    PBR        AvgPBR  \
# 0         4.28     6.039028  1174  856.833333  1894  11862  27450.722220
# 1         3.00     1.500000     0    0.000000   192      0      0.000000
# 2         0.00     1.500000     0    0.000000    96      0      0.000000
# 3         2.96     2.021923     0    0.000000    96      0      0.000000
# 4         0.15     0.159373     0    0.000000    96      0      0.000000
# ...        ...          ...   ...         ...   ...    ...           ...
# 5467     15.08    14.057467   596  580.106667   848    166    162.240000
# 5468      0.00     0.012399    35   38.840843    63    110    141.052849
# 5469      0.12     9.772956    76  356.485402   132    219    927.129562
# 5470      0.45     0.566667    64   54.333333   272    182   3572.000000
# 5471      0.29     0.290000     0    0.000000    96      0      0.000000
#
#         TBR  Missed_Bytes  Packets_Sent  Packets_Received      SRPR
# 0     12462             0            18                15  0.833333
# 1         0             0             4                 0  0.000000
# 2         0             0             2                 0  0.000000
# 3         0             0             2                 0  0.000000
# 4        40             0             2                 1  0.500000
# ...     ...           ...           ...               ...       ...
# 5467    338             0             6                 4  0.666667
# 5468      0             0             1                 0  0.000000
# 5469    247             0             2                 1  0.500000
# 5470    350             0             5                 4  0.800000
# 5471     40             0             2                 1  0.500000
#
# [5472 rows x 12 columns]

# %%
import tensorflow

# %%
y=data["class"]

# %%
y.shape
# Out:
# (5472,)

# %%
#Divide Data into train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4377, 12)
# (1095, 12)
# (4377,)
# (1095,)

# %%
#Scaling
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
# Importing the Keras libraries and packages
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

# %%
classifier=Sequential()

classifier.add(Dense(units=10,kernel_initializer='he_uniform',activation='relu',input_dim =12))

classifier.add(Dense(units = 10, kernel_initializer = 'he_uniform',activation='relu'))

classifier.add(Dense(units = 1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# %%
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy',metrics=['accuracy'])

# %%
classifier.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 10)                130
#
#  dense_4 (Dense)             (None, 10)                110
#
#  dense_5 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 251 (1004.00 Byte)
# Trainable params: 251 (1004.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
X_train
# Out:
# array([[-2.80788373e-02, -3.39658734e-02,  7.95078620e-02, ...,
#         -4.80954796e-02, -7.23613319e-02, -1.84722884e-01],
#        [ 2.01493428e+00,  1.36615026e-01, -1.23826463e-03, ...,
#          9.96274851e-02,  1.34060596e-01,  9.35692896e-01],
#        [-1.47231093e-01, -1.23146857e-01, -9.09207214e-02, ...,
#         -7.41642381e-02, -9.71319633e-02, -1.18401263e+00],
#        ...,
#        [ 3.49822450e-02,  2.46502101e-02, -7.49629889e-02, ...,
#         -7.41642381e-02, -9.71319633e-02, -1.18401263e+00],
#        [ 2.20348637e-01,  3.48200542e-01, -6.69841226e-02, ...,
#         -6.54746519e-02, -8.06182091e-02, -7.36906890e-02],
#        [-1.43580188e-01, -1.50247080e-01, -4.17709052e-02, ...,
#         -4.80954796e-02, -5.58475777e-02,  4.81470282e-01]])

# %%
model_history=classifier.fit(X_train,y_train,batch_size=10,epochs=30,validation_split=0.25)
# Out:
# Epoch 1/30
# 329/329 [==============================] - 7s 4ms/step - loss: 0.5826 - accuracy: 0.6987 - val_loss: 0.5446 - val_accuracy: 0.7160
# Epoch 2/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.5340 - accuracy: 0.7239 - val_loss: 0.5327 - val_accuracy: 0.7196
# Epoch 3/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.5193 - accuracy: 0.7322 - val_loss: 0.5194 - val_accuracy: 0.7260
# Epoch 4/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.5043 - accuracy: 0.7383 - val_loss: 0.5092 - val_accuracy: 0.7215
# Epoch 5/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4913 - accuracy: 0.7410 - val_loss: 0.4978 - val_accuracy: 0.7297
# Epoch 6/30
# 329/329 [==============================] - 2s 5ms/step - loss: 0.4787 - accuracy: 0.7483 - val_loss: 0.4855 - val_accuracy: 0.7260
# Epoch 7/30
# 329/329 [==============================] - 3s 8ms/step - loss: 0.4677 - accuracy: 0.7498 - val_loss: 0.4763 - val_accuracy: 0.7324
# Epoch 8/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4567 - accuracy: 0.7529 - val_loss: 0.4687 - val_accuracy: 0.7434
# Epoch 9/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4503 - accuracy: 0.7575 - val_loss: 0.4598 - val_accuracy: 0.7470
# Epoch 10/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4414 - accuracy: 0.7645 - val_loss: 0.4554 - val_accuracy: 0.7671
# Epoch 11/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4367 - accuracy: 0.7727 - val_loss: 0.4512 - val_accuracy: 0.7571
# Epoch 12/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4326 - accuracy: 0.7709 - val_loss: 0.4478 - val_accuracy: 0.7580
# Epoch 13/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4303 - accuracy: 0.7733 - val_loss: 0.4425 - val_accuracy: 0.7571
# Epoch 14/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4274 - accuracy: 0.7733 - val_loss: 0.4434 - val_accuracy: 0.7927
# Epoch 15/30
# 329/329 [==============================] - 2s 5ms/step - loss: 0.4236 - accuracy: 0.7794 - val_loss: 0.4378 - val_accuracy: 0.7598
# Epoch 16/30
# 329/329 [==============================] - 2s 6ms/step - loss: 0.4215 - accuracy: 0.7821 - val_loss: 0.4393 - val_accuracy: 0.7589
# Epoch 17/30
# 329/329 [==============================] - 2s 5ms/step - loss: 0.4187 - accuracy: 0.7782 - val_loss: 0.4354 - val_accuracy: 0.7580
# Epoch 18/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4168 - accuracy: 0.7824 - val_loss: 0.4344 - val_accuracy: 0.7543
# Epoch 19/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4183 - accuracy: 0.7806 - val_loss: 0.4325 - val_accuracy: 0.7699
# Epoch 20/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4156 - accuracy: 0.7785 - val_loss: 0.4290 - val_accuracy: 0.7589
# Epoch 21/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4133 - accuracy: 0.7861 - val_loss: 0.4305 - val_accuracy: 0.7571
# Epoch 22/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4115 - accuracy: 0.7824 - val_loss: 0.4280 - val_accuracy: 0.7626
# Epoch 23/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4100 - accuracy: 0.7840 - val_loss: 0.4254 - val_accuracy: 0.7854
# Epoch 24/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4121 - accuracy: 0.7821 - val_loss: 0.4210 - val_accuracy: 0.7598
# Epoch 25/30
# 329/329 [==============================] - 2s 6ms/step - loss: 0.4070 - accuracy: 0.7837 - val_loss: 0.4175 - val_accuracy: 0.7872
# Epoch 26/30
# 329/329 [==============================] - 2s 6ms/step - loss: 0.4064 - accuracy: 0.7882 - val_loss: 0.4178 - val_accuracy: 0.7927
# Epoch 27/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4056 - accuracy: 0.7925 - val_loss: 0.4158 - val_accuracy: 0.7689
# Epoch 28/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4032 - accuracy: 0.7858 - val_loss: 0.4174 - val_accuracy: 0.7562
# Epoch 29/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4033 - accuracy: 0.7876 - val_loss: 0.4136 - val_accuracy: 0.7616
# Epoch 30/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4030 - accuracy: 0.7892 - val_loss: 0.4126 - val_accuracy: 0.7945

# %%
model_history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
model_history.history['accuracy']
# Out:
# [0.698659360408783,
#  0.7239488363265991,
#  0.7321755290031433,
#  0.7382693290710449,
#  0.7410115599632263,
#  0.7483242154121399,
#  0.7498476505279541,
#  0.7528945803642273,
#  0.7574649453163147,
#  0.7644729018211365,
#  0.7726995944976807,
#  0.7708714008331299,
#  0.7733089327812195,
#  0.7733089327812195,
#  0.7794027924537659,
#  0.7821450233459473,
#  0.7781840562820435,
#  0.7824497222900391,
#  0.7806215882301331,
#  0.7784887552261353,
#  0.7861060500144958,
#  0.7824497222900391,
#  0.7839731574058533,
#  0.7821450233459473,
#  0.7836685180664062,
#  0.7882388830184937,
#  0.7925045490264893,
#  0.785801351070404,
#  0.7876294851303101,
#  0.789152979850769]

# %%
# list all data in history

print(model_history.history.keys())
# summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for accuracy
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model accuracy')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
X_test.shape
# Out:
# (1095, 12)

# %%
y_pred=classifier.predict(X_test)
# Out:
# 35/35 [==============================] - 0s 2ms/step

# %%
#for the sigmoid my threshold is 0.
y_pred=y_pred>0.5

# %%
from sklearn.metrics import confusion_matrix

# %%
y_test.shape
# Out:
# (1095,)

# %%
y_pred.shape
# Out:
# (1095, 1)

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[282, 105],
#        [102, 606]])

# %%
import time
import os

def saveModel_path(model_dir="SAVED_MODELS"):
    os.makedirs(model_dir, exist_ok=True)
    fileName = time.strftime("Model_%Y_%m_%d_%H_%M_%S_.h5")
    model_path = os.path.join(model_dir, fileName)
    print(f"your model will be saved at the following location\n{model_path}")
    return model_path

# %%
classifier.save(saveModel_path())
# Out:
# your model will be saved at the following location
# SAVED_MODELS/Model_2023_12_08_13_15_39_.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
#hyperparameter tunig with keras tuner

# !pip install keras-tuner --upgrade
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.6-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.9/128.9 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.14.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2023.11.17)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.6 kt-legacy-1.0.5

# %%
from kerastuner.tuners import RandomSearch
# Out:
# <ipython-input-64-94471a811b41>:1: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import RandomSearch

# %%
def build_model(hp):
  model=Sequential()
  model.add(Dense(units=32,kernel_initializer = 'he_uniform',activation='relu',input_dim=12))
  model.add(Dense(units = 32, kernel_initializer = 'he_uniform',activation='relu'))
  model.add(Dense(1,activation='sigmoid'))
  optimizer=hp.Choice("optimizer",values=["adam","sgd","rmsprop","adadelta"])
  model.compile(optimizer=optimizer,loss='binary_crossentropy',metrics=['accuracy'])
  return model

# %%
tuner=RandomSearch(build_model,objective='val_accuracy',max_trials=5,directory='project1',project_name='aps-fault')

# %%
tuner.search(X_train,y_train,validation_data=(X_test,y_test),epochs=5)
# Out:
# Trial 4 Complete [00h 00m 06s]
# val_accuracy: 0.7269406318664551
#
# Best val_accuracy So Far: 0.759817361831665
# Total elapsed time: 00h 00m 23s

# %%
tuner.get_best_hyperparameters()[0].values
# Out:
# {'optimizer': 'rmsprop'}

# %%
mymodel=tuner.get_best_models(num_models=1)[0]

# %%
mymodel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                416
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1505 (5.88 KB)
# Trainable params: 1505 (5.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras import optimizers
def build_model(hp):
    model = Sequential()
    for i in range(hp.Int('num_layers', 2, 20)):
        model.add(Dense(units=hp.Int('units_' + str(i),
                                            min_value=32,
                                            max_value=512,
                                            step=32),
                               activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(
        optimizer=optimizers.Adam(
            hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
        loss='binary_crossentropy',
        metrics=['accuracy'])
    return model

# %%
tuner_second=RandomSearch(build_model,objective='val_accuracy',max_trials=5,directory='project3',project_name='aps-fault-sensor')

# %%
tuner_second.search(X_train,y_train,epochs=5,validation_data=(X_test,y_test))
# Out:
# Trial 5 Complete [00h 00m 14s]
# val_accuracy: 0.7863013744354248
#
# Best val_accuracy So Far: 0.7863013744354248
# Total elapsed time: 00h 01m 01s

# %%
tuner_second.get_best_hyperparameters()[0].values
# Out:
# {'num_layers': 17,
#  'units_0': 480,
#  'units_1': 480,
#  'learning_rate': 0.0001,
#  'units_2': 64,
#  'units_3': 416,
#  'units_4': 416,
#  'units_5': 512,
#  'units_6': 480,
#  'units_7': 256,
#  'units_8': 384,
#  'units_9': 224,
#  'units_10': 256,
#  'units_11': 32,
#  'units_12': 480,
#  'units_13': 256,
#  'units_14': 32,
#  'units_15': 192,
#  'units_16': 448}
